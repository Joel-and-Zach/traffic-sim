# %%
from trafficsim.car import Car
from trafficsim.simulation import Simulation
import matplotlib.pyplot as plt
import seaborn as sn
import statistics as st

# %%
# %matplotlib inline

# %%
simulation = Simulation()

# %%
traffic_speed, traffic_position = simulation.simulate(360)

# %%
time = [[n for n in range(30)] for n in range(300)]

# %% [markdown]
# # Traffic Density Over time of 4 Minutes

# %%
plt.figure(figsize=(7,7))
plt.scatter(traffic_position, time, marker=',', color='black', alpha=.2)
plt.xlabel('Kilometer')
plt.ylabel('Time')
plt.show()
